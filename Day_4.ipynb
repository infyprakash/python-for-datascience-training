# %% [markdown]
# <a href="https://colab.research.google.com/github/infyprakash/python-for-datascience-training/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bangalore Housing Dataset:**
# url: https://www.kaggle.com/ruchi798/housing-prices-in-metropolitan-areas-of-india?select=Bangalore.csv
#
#
# # **Netflix Tv and Movies:**
#
# url: https://www.kaggle.com/shivamb/netflix-shows
#
# Interesting Task Ideas
# - Understanding what content is available in different countries
# - Identifying similar content by matching text-based features
# - Network analysis of Actors / Directors and find interesting insights
# - Does Netflix has more focus on TV Shows than movies in recent years.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Netflix/netflix_titles.csv"

# %%
netflix_df = pd.read_csv(path)

# %%
netflix_df.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  As her father nears the end of his life, filmm...
# 1      s2  ...  After crossing paths at a party, a Cape Town t...
# 2      s3  ...  To protect his family from a powerful drug lor...
# 3      s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4      s5  ...  In a city of coaching centers known to train I...
#
# [5 rows x 12 columns]

# %%
print(list(netflix_df.columns))
# Out:
# ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']

# %% [markdown]
# ### Total number of show type

# %%
types = netflix_df["type"].value_counts()
print(types)
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
x = np.array(types.index)

# %%
y = np.array(types.values)

# %%
sns.barplot(x=x,y=y)
plt.show()

# %% [markdown]
# The above bar plot shows, Netflix produces more movies than Tv Shows

# %% [markdown]
# ### Number of missing values in each columns

# %%
netflix_df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ### Most number of releases- year wise

# %%
year = netflix_df["release_year"].value_counts()
print(year[:10])
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# Name: release_year, dtype: int64

# %%
x = np.array(year.index)
y = np.array(year.values)

# %%
plt.figure(figsize=(25,5))
sns.barplot(x=x,y=y)
plt.show()

# %%
year = netflix_df["release_year"].value_counts()[:10]

# %%
x = np.array(year.index)
y = np.array(year.values)

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=x,y=y)
plt.show()

# %% [markdown]
# # Bangalore Housing Dataset

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Housing/Bangalore.csv"

# %%
h_df = pd.read_csv(path)

# %%
h_df.head()
# Out:
#       Price  Area  ... Wardrobe  Refrigerator
# 0  30000000  3340  ...        0             0
# 1   7888000  1045  ...        0             0
# 2   4866000  1179  ...        0             0
# 3   8358000  1675  ...        0             0
# 4   6845000  1670  ...        0             0
#
# [5 rows x 40 columns]

# %%
h_df.columns
# Out:
# Index(['Price', 'Area', 'Location', 'No. of Bedrooms', 'Resale',
#        'MaintenanceStaff', 'Gymnasium', 'SwimmingPool', 'LandscapedGardens',
#        'JoggingTrack', 'RainWaterHarvesting', 'IndoorGames', 'ShoppingMall',
#        'Intercom', 'SportsFacility', 'ATM', 'ClubHouse', 'School',
#        '24X7Security', 'PowerBackup', 'CarParking', 'StaffQuarter',
#        'Cafeteria', 'MultipurposeRoom', 'Hospital', 'WashingMachine',
#        'Gasconnection', 'AC', 'Wifi', 'Children'splayarea', 'LiftAvailable',
#        'BED', 'VaastuCompliant', 'Microwave', 'GolfCourse', 'TV',
#        'DiningTable', 'Sofa', 'Wardrobe', 'Refrigerator'],
#       dtype='object')

# %%
h_df.describe().T
# Out:
#                       count          mean  ...         75%          max
# Price                6207.0  1.058510e+07  ...  10700000.0  300000000.0
# Area                 6207.0  1.526094e+03  ...      1662.5       9900.0
# No. of Bedrooms      6207.0  2.556952e+00  ...         3.0          7.0
# Resale               6207.0  7.878202e-02  ...         0.0          1.0
# MaintenanceStaff     6207.0  6.208797e+00  ...         9.0          9.0
# Gymnasium            6207.0  6.461576e+00  ...         9.0          9.0
# SwimmingPool         6207.0  6.436121e+00  ...         9.0          9.0
# LandscapedGardens    6207.0  6.382471e+00  ...         9.0          9.0
# JoggingTrack         6207.0  6.396649e+00  ...         9.0          9.0
# RainWaterHarvesting  6207.0  6.373933e+00  ...         9.0          9.0
# IndoorGames          6207.0  6.348639e+00  ...         9.0          9.0
# ShoppingMall         6207.0  6.207024e+00  ...         9.0          9.0
# ...

# %%
len(h_df.values)
# Out:
# 6207

# %% [markdown]
# ### Calculate avarage housing price

# %%
average_price = np.mean(h_df['Price'])

# %%
print("Average hosuing price: INR",average_price)
# Out:
# Average hosuing price: INR 10585104.825519575

# %% [markdown]
# ### distribution of housing price

# %%
np.std(h_df['Price'])
# Out:
# 14108297.374997266

# %% [markdown]
# very high standard deviation indicates, high variability in prices, which can be verified by histplot shown below:

# %%
plt.figure(figsize=(20,5))
sns.histplot(data=h_df,x="Price")

# %% [markdown]
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(15,5))
sns.boxplot(data=h_df,x="Price")

# %%
location_price = h_df.groupby('Location',as_index=False).mean()[["Location","Price"]]

# %%
location_price = location_price.sort_values(by="Price",ascending=False)

# %%
location_price['Location'].tail()
# Out:
# 188    Kumaraswamy Layout Vittal Nagar
# 264                    Seegehalli Road
# 269                            Sompura
# 183                Krishna Garden Road
# 87                       Domlur Layout
# Name: Location, dtype: object

# %%
location_price['Location'].head()
# Out:
# 252               Richmond Town
# 41     Bannerghatta Road Jigani
# 159                     Kalkere
# 44                 Basavanagudi
# 136            JP Nagar Phase 6
# Name: Location, dtype: object

# %%
cols = ['Richmond Town','Bannerghatta Road Jigani','Kalkere','Basavanagudi','JP Nagar Phase 6','Domlur Layout','Krishna Garden Road']

# %%
loc_price = h_df.loc[h_df['Location'].isin(cols)][['Location','Price','Area']]

# %%
loc_price.head()
# Out:
#               Location     Price  Area
# 901      Richmond Town  64000000  2772
# 1049  JP Nagar Phase 6  61300000  5600
# 1050  JP Nagar Phase 6  57500000  5249
# 1051  JP Nagar Phase 6  48700000  4449
# 1052  JP Nagar Phase 6  30900000  3103

# %%
sns.boxplot(data=loc_price,x='Price',y='Location',orient='h')

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10,100))
sns.boxplot(data=h_df,x='Price',y='Location',orient='h')

# %% [markdown]
# Let us explore, how Area and house price is related:

# %%
sns.scatterplot(data=h_df,x="Area",y="Price")

# %%
sns.relplot(data=h_df,x="Area",y="Price",hue="Location",style="Location")

# %%
sns.relplot(data=h_df,x='No. of Bedrooms',y="Price")

# %%
corr1 = h_df.corr()

# %%
corr1
# Out:
#                         Price      Area  ...  Wardrobe  Refrigerator
# Price                1.000000  0.397626  ...  0.030335      0.033460
# Area                 0.397626  1.000000  ...  0.009288      0.013166
# No. of Bedrooms      0.234272  0.733010  ...  0.024300      0.027576
# Resale              -0.038024  0.021379  ... -0.033874     -0.036538
# MaintenanceStaff     0.030497  0.008910  ...  0.999025      0.998159
# Gymnasium            0.031976  0.011436  ...  0.999217      0.998334
# SwimmingPool         0.034450  0.014659  ...  0.998554      0.997864
# LandscapedGardens    0.029744  0.011841  ...  0.997692      0.996873
# JoggingTrack         0.035339  0.016572  ...  0.997853      0.996902
# RainWaterHarvesting  0.033558  0.012948  ...  0.997617      0.996563
# IndoorGames          0.033942  0.013533  ...  0.997490      0.996653
# ShoppingMall         0.029271  0.008135  ...  0.999066      0.997967
# Intercom             0.030951  0.008993  ...  0.998221      0.997658
# ...

# %%
corr2 = h_df.corr()[["Price","Area","No. of Bedrooms"]]
corr2
# Out:
#                         Price      Area  No. of Bedrooms
# Price                1.000000  0.397626         0.234272
# Area                 0.397626  1.000000         0.733010
# No. of Bedrooms      0.234272  0.733010         1.000000
# Resale              -0.038024  0.021379        -0.015806
# MaintenanceStaff     0.030497  0.008910         0.024080
# Gymnasium            0.031976  0.011436         0.027791
# SwimmingPool         0.034450  0.014659         0.031352
# LandscapedGardens    0.029744  0.011841         0.028554
# JoggingTrack         0.035339  0.016572         0.030822
# RainWaterHarvesting  0.033558  0.012948         0.028072
# IndoorGames          0.033942  0.013533         0.029305
# ShoppingMall         0.029271  0.008135         0.023286
# Intercom             0.030951  0.008993         0.025169
# SportsFacility       0.036435  0.016626         0.030582
# ATM                  0.029886  0.009310         0.024654
# ...

# %%
sns.heatmap(corr1)
